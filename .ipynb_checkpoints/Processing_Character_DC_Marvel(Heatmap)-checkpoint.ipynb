# %%
#Heatmap of Appearances, with first appearance, and character

# %%
import pandas as pd

# %%
data_dir = '/Users/ksivanathan/Desktop/USF/DataViz/FinalProject_Comics/Datasets/'

# %% [markdown]
# ### Marvel Data

# %%
marvel = pd.read_csv(data_dir + 'marvel_data_OG.csv')

# %%
marvel
# Out:
#        page_id                                 name  \
# 0         1678            Spider-Man (Peter Parker)
# 1         7139      Captain America (Steven Rogers)
# 2        64786  Wolverine (James \"Logan\" Howlett)
# 3         1868    Iron Man (Anthony \"Tony\" Stark)
# 4         2460                  Thor (Thor Odinson)
# ...        ...                                  ...
# 16371   657508                   Ru'ach (Earth-616)
# 16372   665474      Thane (Thanos' son) (Earth-616)
# 16373   695217        Tinkerer (Skrull) (Earth-616)
# 16374   708811       TK421 (Spiderling) (Earth-616)
# 16375   673702                Yologarch (Earth-616)
#
#                                        urlslug                ID  \
# 0                  \/Spider-Man_(Peter_Parker)   Secret Identity
# 1            \/Captain_America_(Steven_Rogers)   Public Identity
# 2      \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3        \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# ...

# %%
marvel.isna().sum()
# Out:
# page_id                 0
# name                    0
# urlslug                 0
# ID                   3770
# ALIGN                2812
# EYE                  9767
# HAIR                 4264
# SEX                   854
# GSM                 16286
# ALIVE                   3
# APPEARANCES          1096
# FIRST APPEARANCE      815
# Year                  815
# dtype: int64

# %%
marvel_clean = marvel.drop(['GSM','HAIR','ALIVE','ALIGN','EYE','page_id','urlslug','ID','SEX','FIRST APPEARANCE'], axis = 1)

# %%
marvel_clean = marvel_clean.dropna()

# %%
marvel_clean.isna().sum()
# Out:
# name           0
# APPEARANCES    0
# Year           0
# dtype: int64

# %%
marvel_clean
# Out:
#                                                   name  APPEARANCES    Year
# 0                            Spider-Man (Peter Parker)       4043.0  1962.0
# 1                      Captain America (Steven Rogers)       3360.0  1941.0
# 2                  Wolverine (James \"Logan\" Howlett)       3061.0  1974.0
# 3                    Iron Man (Anthony \"Tony\" Stark)       2961.0  1963.0
# 4                                  Thor (Thor Odinson)       2258.0  1950.0
# ...                                                ...          ...     ...
# 15034                   War (11th Century) (Earth-616)          1.0  2013.0
# 15035               William Henry Harrison (Earth-616)          1.0  2013.0
# 15036  Wormwhole Wodo (Legion Personality) (Earth-616)          1.0  2013.0
# 15037                       Zachary Taylor (Earth-616)          1.0  2013.0
# 15038           Zubar (Legion Personality) (Earth-616)          1.0  2013.0
#
# [14665 rows x 3 columns]

# %% [markdown]
# ### DC Data

# %%
dc = pd.read_csv(data_dir + 'DC_data_OG.csv')

# %%
dc
# Out:
#       page_id                          name  \
# 0        1422          Batman (Bruce Wayne)
# 1       23387         Superman (Clark Kent)
# 2        1458    Green Lantern (Hal Jordan)
# 3        1659      James Gordon (New Earth)
# 4        1576   Richard Grayson (New Earth)
# ...       ...                           ...
# 6891    66302       Nadine West (New Earth)
# 6892   283475    Warren Harding (New Earth)
# 6893   283478  William Harrison (New Earth)
# 6894   283471  William McKinley (New Earth)
# 6895   150660            Mookie (New Earth)
#
#                                    urlslug               ID            ALIGN  \
# 0             \/wiki\/Batman_(Bruce_Wayne)  Secret Identity  Good Characters
# 1            \/wiki\/Superman_(Clark_Kent)  Secret Identity  Good Characters
# 2       \/wiki\/Green_Lantern_(Hal_Jordan)  Secret Identity  Good Characters
# 3         \/wiki\/James_Gordon_(New_Earth)  Public Identity  Good Characters
# ...

# %%
dc.isna().sum()
# Out:
# page_id                0
# name                   0
# urlslug                0
# ID                  2013
# ALIGN                601
# EYE                 3628
# HAIR                2274
# SEX                  125
# GSM                 6832
# ALIVE                  3
# APPEARANCES          355
# FIRST APPEARANCE      69
# YEAR                  69
# dtype: int64

# %%
dc_clean = dc.drop(['GSM','HAIR','ALIVE','ALIGN','EYE','page_id','urlslug','ID','SEX','FIRST APPEARANCE'], axis = 1)

# %%
dc_clean = dc_clean.dropna()

# %%
dc_clean.isna().sum()
# Out:
# name           0
# APPEARANCES    0
# YEAR           0
# dtype: int64

# %%
dc_clean
# Out:
#                               name  APPEARANCES    YEAR
# 0             Batman (Bruce Wayne)       3093.0  1939.0
# 1            Superman (Clark Kent)       2496.0  1986.0
# 2       Green Lantern (Hal Jordan)       1565.0  1959.0
# 3         James Gordon (New Earth)       1316.0  1987.0
# 4      Richard Grayson (New Earth)       1237.0  1940.0
# ...                            ...          ...     ...
# 6527     Gypper Zilich (New Earth)          1.0  1941.0
# 6528      Robert Mason (New Earth)          1.0  1941.0
# 6529  Diablo the Horse (New Earth)          1.0  1940.0
# 6530     Scott Scanlon (New Earth)          1.0  1938.0
# 6531            Gareth (New Earth)          1.0  1936.0
#
# [6481 rows x 3 columns]

# %% [markdown]
# ### Joining the Datasets

# %%
dc_clean = dc_clean.rename(columns={'YEAR':'Year'})

# %%
join = [dc_clean,marvel_clean]

# %%
appearances = pd.concat(join)

# %%
appearances['Year'] = appearances['Year'].astype(int)
appearances['APPEARANCES'] = appearances['APPEARANCES'].astype(int)

# %%
appearances = appearances.sort_values(by='APPEARANCES', ascending=False)

# %%
appearances['year'] = appearances['Year'] // 10 * 10

# %%
appearances = appearances.drop(['Year'],axis=1)

# %%
appearances = appearances[appearances['APPEARANCES'] >= 500]

# %%
appearances
# Out:
#                                    name  APPEARANCES  year
# 0             Spider-Man (Peter Parker)         4043  1960
# 1       Captain America (Steven Rogers)         3360  1940
# 0                  Batman (Bruce Wayne)         3093  1930
# 2   Wolverine (James \"Logan\" Howlett)         3061  1970
# 3     Iron Man (Anthony \"Tony\" Stark)         2961  1960
# ..                                  ...          ...   ...
# 67      Crystalia Amaquelin (Earth-616)          512  1960
# 68            Samuel Wilson (Earth-616)          512  1960
# 69              Wilson Fisk (Earth-616)          503  1960
# 70              Odin Borson (Earth-616)          502  1960
# 71               Deadpool (Wade Wilson)          500  1990
#
# [101 rows x 3 columns]

# %%
#Getting the top 10 values

# %%
top10 = appearances.nlargest(10,columns='APPEARANCES')
top10
# Out:
#                                   name  APPEARANCES  year
# 0            Spider-Man (Peter Parker)         4043  1960
# 1      Captain America (Steven Rogers)         3360  1940
# 0                 Batman (Bruce Wayne)         3093  1930
# 2  Wolverine (James \"Logan\" Howlett)         3061  1970
# 3    Iron Man (Anthony \"Tony\" Stark)         2961  1960
# 1                Superman (Clark Kent)         2496  1980
# 4                  Thor (Thor Odinson)         2258  1950
# 5           Benjamin Grimm (Earth-616)         2255  1960
# 6            Reed Richards (Earth-616)         2072  1960
# 7           Hulk (Robert Bruce Banner)         2017  1960

# %%
top10.to_csv(data_dir + 'top10.csv', index = False)

# %%
appearances.to_csv(data_dir + 'appearances.csv', index = False)
