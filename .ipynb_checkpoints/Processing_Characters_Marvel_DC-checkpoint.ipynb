# %%
import pandas as pd
from sklearn import preprocessing

# %%
data_dir = '/Users/ksivanathan/Desktop/USF/DataViz/FinalProject_Comics/Datasets/'

# %% [markdown]
# ### Marvel Dataset

# %%
marvel = pd.read_csv(data_dir + 'marvel_data_OG.csv')

# %%
marvel
# Out:
#        page_id                                 name  \
# 0         1678            Spider-Man (Peter Parker)
# 1         7139      Captain America (Steven Rogers)
# 2        64786  Wolverine (James \"Logan\" Howlett)
# 3         1868    Iron Man (Anthony \"Tony\" Stark)
# 4         2460                  Thor (Thor Odinson)
# ...        ...                                  ...
# 16371   657508                   Ru'ach (Earth-616)
# 16372   665474      Thane (Thanos' son) (Earth-616)
# 16373   695217        Tinkerer (Skrull) (Earth-616)
# 16374   708811       TK421 (Spiderling) (Earth-616)
# 16375   673702                Yologarch (Earth-616)
#
#                                        urlslug                ID  \
# 0                  \/Spider-Man_(Peter_Parker)   Secret Identity
# 1            \/Captain_America_(Steven_Rogers)   Public Identity
# 2      \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3        \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# ...

# %%
marvel.shape
# Out:
# (16376, 13)

# %%
marvel.nunique(axis=0) # Shows the unique values for each column
# Out:
# page_id             16376
# name                16376
# urlslug             16376
# ID                      4
# ALIGN                   3
# EYE                    24
# HAIR                   25
# SEX                     4
# GSM                     6
# ALIVE                   2
# APPEARANCES           358
# FIRST APPEARANCE      832
# Year                   75
# dtype: int64

# %%
marvel['GSM'].unique()
# Out:
# array([nan, 'Bisexual Characters', 'Transvestites',
#        'Homosexual Characters', 'Pansexual Characters',
#        'Transgender Characters', 'Genderfluid Characters'], dtype=object)

# %%
marvel['ALIGN'].unique()
# Out:
# array(['Good Characters', 'Neutral Characters', 'Bad Characters', nan],
#       dtype=object)

# %%
marvel['ID'].unique()
# Out:
# array(['Secret Identity', 'Public Identity', 'No Dual Identity',
#        'Known to Authorities Identity', nan], dtype=object)

# %%
marvel['ALIVE'].unique()
# Out:
# array(['Living Characters', 'Deceased Characters', nan], dtype=object)

# %%
marvel['SEX'].unique()
# Out:
# array(['Male Characters', 'Female Characters', 'Genderfluid Characters',
#        'Agender Characters', nan], dtype=object)

# %% [markdown]
# ### Cleaning the Data

# %%
marvel.isna().sum()
# Out:
# page_id                 0
# name                    0
# urlslug                 0
# ID                   3770
# ALIGN                2812
# EYE                  9767
# HAIR                 4264
# SEX                   854
# GSM                 16286
# ALIVE                   3
# APPEARANCES          1096
# FIRST APPEARANCE      815
# Year                  815
# dtype: int64

# %%
#Percentage Missing
(marvel.isna().sum() / len(marvel))*100
# Out:
# page_id              0.000000
# name                 0.000000
# urlslug              0.000000
# ID                  23.021495
# ALIGN               17.171470
# EYE                 59.642159
# HAIR                26.038105
# SEX                  5.214949
# GSM                 99.450415
# ALIVE                0.018319
# APPEARANCES          6.692721
# FIRST APPEARANCE     4.976795
# Year                 4.976795
# dtype: float64

# %%
#Remove GSM, HAIR, EYE, FIRST APPEARANCE, Year, urlslug,APPEARANCES
marvel_clean = marvel.drop(['GSM','HAIR','FIRST APPEARANCE','APPEARANCES','EYE','Year','urlslug'], axis = 1)

# %%
#Create column 'Universe' == Marvel 
marvel_clean['Universe'] = 'Marvel'

# %%
#Filling the missing values for ALIGN, ID, ALIVE, SEX

# %%
marvel_clean['ALIGN'] = marvel_clean['ALIGN'].fillna('Neutral Characters')

# %%
marvel_clean['ID'] = marvel_clean['ID'].fillna('Secret Identity')

# %%
marvel_clean['ALIVE'] = marvel_clean['ALIVE'].fillna('Unknown')

# %%
marvel_clean['SEX'] = marvel_clean['SEX'].fillna('Unknown')

# %%
marvel_clean
# Out:
#        page_id                                 name                ID  \
# 0         1678            Spider-Man (Peter Parker)   Secret Identity
# 1         7139      Captain America (Steven Rogers)   Public Identity
# 2        64786  Wolverine (James \"Logan\" Howlett)   Public Identity
# 3         1868    Iron Man (Anthony \"Tony\" Stark)   Public Identity
# 4         2460                  Thor (Thor Odinson)  No Dual Identity
# ...        ...                                  ...               ...
# 16371   657508                   Ru'ach (Earth-616)  No Dual Identity
# 16372   665474      Thane (Thanos' son) (Earth-616)  No Dual Identity
# 16373   695217        Tinkerer (Skrull) (Earth-616)   Secret Identity
# 16374   708811       TK421 (Spiderling) (Earth-616)   Secret Identity
# 16375   673702                Yologarch (Earth-616)   Secret Identity
#
#                     ALIGN              SEX              ALIVE Universe
# ...

# %% [markdown]
# ### DC Dataset

# %%
dc = pd.read_csv(data_dir + 'DC_data_OG.csv')

# %%
dc
# Out:
#       page_id                          name  \
# 0        1422          Batman (Bruce Wayne)
# 1       23387         Superman (Clark Kent)
# 2        1458    Green Lantern (Hal Jordan)
# 3        1659      James Gordon (New Earth)
# 4        1576   Richard Grayson (New Earth)
# ...       ...                           ...
# 6891    66302       Nadine West (New Earth)
# 6892   283475    Warren Harding (New Earth)
# 6893   283478  William Harrison (New Earth)
# 6894   283471  William McKinley (New Earth)
# 6895   150660            Mookie (New Earth)
#
#                                    urlslug               ID            ALIGN  \
# 0             \/wiki\/Batman_(Bruce_Wayne)  Secret Identity  Good Characters
# 1            \/wiki\/Superman_(Clark_Kent)  Secret Identity  Good Characters
# 2       \/wiki\/Green_Lantern_(Hal_Jordan)  Secret Identity  Good Characters
# 3         \/wiki\/James_Gordon_(New_Earth)  Public Identity  Good Characters
# ...

# %%
dc.shape
# Out:
# (6896, 13)

# %%
dc.nunique(axis=0) # Shows the unique values for each column
# Out:
# page_id             6896
# name                6896
# urlslug             6896
# ID                     3
# ALIGN                  4
# EYE                   17
# HAIR                  17
# SEX                    4
# GSM                    2
# ALIVE                  2
# APPEARANCES          282
# FIRST APPEARANCE     774
# YEAR                  79
# dtype: int64

# %%
dc['GSM'].unique()
# Out:
# array([nan, 'Bisexual Characters', 'Homosexual Characters'], dtype=object)

# %%
dc['ALIGN'].unique()
# Out:
# array(['Good Characters', 'Bad Characters', 'Neutral Characters', nan,
#        'Reformed Criminals'], dtype=object)

# %%
dc['SEX'].unique()
# Out:
# array(['Male Characters', 'Female Characters', nan,
#        'Genderless Characters', 'Transgender Characters'], dtype=object)

# %%
dc['ID'].unique()
# Out:
# array(['Secret Identity', 'Public Identity', nan, 'Identity Unknown'],
#       dtype=object)

# %%
dc['ALIVE'].unique()
# Out:
# array(['Living Characters', 'Deceased Characters', nan], dtype=object)

# %% [markdown]
# ### Cleaning the Data

# %%
dc.isna().sum()
# Out:
# page_id                0
# name                   0
# urlslug                0
# ID                  2013
# ALIGN                601
# EYE                 3628
# HAIR                2274
# SEX                  125
# GSM                 6832
# ALIVE                  3
# APPEARANCES          355
# FIRST APPEARANCE      69
# YEAR                  69
# dtype: int64

# %%
(dc.isna().sum() / len(dc))*100
# Out:
# page_id              0.000000
# name                 0.000000
# urlslug              0.000000
# ID                  29.190835
# ALIGN                8.715197
# EYE                 52.610209
# HAIR                32.975638
# SEX                  1.812645
# GSM                 99.071926
# ALIVE                0.043503
# APPEARANCES          5.147912
# FIRST APPEARANCE     1.000580
# YEAR                 1.000580
# dtype: float64

# %%
#Remove GSM, HAIR, EYE, FIRST APPEARANCE, YEAR, urlslug,APPEARANCES
dc_clean = dc.drop(['GSM','HAIR','FIRST APPEARANCE','APPEARANCES','EYE','YEAR','urlslug'], axis = 1)

# %%
dc_clean
# Out:
#       page_id                          name               ID            ALIGN  \
# 0        1422          Batman (Bruce Wayne)  Secret Identity  Good Characters
# 1       23387         Superman (Clark Kent)  Secret Identity  Good Characters
# 2        1458    Green Lantern (Hal Jordan)  Secret Identity  Good Characters
# 3        1659      James Gordon (New Earth)  Public Identity  Good Characters
# 4        1576   Richard Grayson (New Earth)  Secret Identity  Good Characters
# ...       ...                           ...              ...              ...
# 6891    66302       Nadine West (New Earth)  Public Identity  Good Characters
# 6892   283475    Warren Harding (New Earth)  Public Identity  Good Characters
# 6893   283478  William Harrison (New Earth)  Public Identity  Good Characters
# 6894   283471  William McKinley (New Earth)  Public Identity  Good Characters
# 6895   150660            Mookie (New Earth)  Public Identity   Bad Characters
#
# ...

# %%
#Create column 'Universe' == DC 
dc_clean['Universe'] = 'DC'

# %%
#Filling the missing values for ID, ALIGN, SEX, ALIVE

# %%
dc_clean['ALIGN'] = dc_clean['ALIGN'].fillna('Neutral Characters')

# %%
dc_clean['ID'] = dc_clean['ID'].fillna('Identity Unknown')

# %%
dc_clean['ALIVE'] = dc_clean['ALIVE'].fillna('Unknown')

# %%
dc_clean['SEX'] = dc_clean['SEX'].fillna('Unknown')

# %%
dc_clean
# Out:
#       page_id                          name               ID            ALIGN  \
# 0        1422          Batman (Bruce Wayne)  Secret Identity  Good Characters
# 1       23387         Superman (Clark Kent)  Secret Identity  Good Characters
# 2        1458    Green Lantern (Hal Jordan)  Secret Identity  Good Characters
# 3        1659      James Gordon (New Earth)  Public Identity  Good Characters
# 4        1576   Richard Grayson (New Earth)  Secret Identity  Good Characters
# ...       ...                           ...              ...              ...
# 6891    66302       Nadine West (New Earth)  Public Identity  Good Characters
# 6892   283475    Warren Harding (New Earth)  Public Identity  Good Characters
# 6893   283478  William Harrison (New Earth)  Public Identity  Good Characters
# 6894   283471  William McKinley (New Earth)  Public Identity  Good Characters
# 6895   150660            Mookie (New Earth)  Public Identity   Bad Characters
#
# ...

# %% [markdown]
# ### Joining the DC and Marvel Datasets

# %%
join = [dc_clean,marvel_clean]

# %%
dc_marvel = pd.concat(join)

# %%
dc_marvel['ALIGN'] = dc_marvel['ALIGN'].str.replace('Good Characters','Good')
dc_marvel['ALIGN'] = dc_marvel['ALIGN'].str.replace('Bad Characters','Bad')
dc_marvel['ALIGN'] = dc_marvel['ALIGN'].str.replace('Neutral Characters','Neutral')

# %%
dc_marvel['SEX'] = dc_marvel['SEX'].str.replace('Male Characters','Male')
dc_marvel['SEX'] = dc_marvel['SEX'].str.replace('Female Characters','Female')
dc_marvel['SEX'] = dc_marvel['SEX'].str.replace('Genderless Characters','Genderless')
dc_marvel['SEX'] = dc_marvel['SEX'].str.replace('Transgender Characters','Transgender')
dc_marvel['SEX'] = dc_marvel['SEX'].str.replace('Genderfluid Characters','Genderfluid')
dc_marvel['SEX'] = dc_marvel['SEX'].str.replace('Agender Characters','A-Gender')

# %%
dc_marvel['ALIVE'] = dc_marvel['ALIVE'].str.replace('Living Characters','Living')
dc_marvel['ALIVE'] = dc_marvel['ALIVE'].str.replace('Deceased Characters','Deceased')

# %%
dc_marvel = dc_marvel.drop(['page_id'], axis = 1)

# %%
#Removing Characters who have a neutral alignment
dc_marvel = dc_marvel[dc_marvel['ALIGN'] != 'Neutral']

# %%
dc_marvel
# Out:
#                                   name                ID ALIGN      SEX  \
# 0                 Batman (Bruce Wayne)   Secret Identity  Good     Male
# 1                Superman (Clark Kent)   Secret Identity  Good     Male
# 2           Green Lantern (Hal Jordan)   Secret Identity  Good     Male
# 3             James Gordon (New Earth)   Public Identity  Good     Male
# 4          Richard Grayson (New Earth)   Secret Identity  Good     Male
# ...                                ...               ...   ...      ...
# 16369       Melanie Kapoor (Earth-616)   Public Identity  Good   Female
# 16371               Ru'ach (Earth-616)  No Dual Identity   Bad     Male
# 16372  Thane (Thanos' son) (Earth-616)  No Dual Identity  Good     Male
# 16373    Tinkerer (Skrull) (Earth-616)   Secret Identity   Bad     Male
# 16375            Yologarch (Earth-616)   Secret Identity   Bad  Unknown
#
#         ALIVE Universe
# 0      Living       DC
# 1      Living       DC
# 2      Living       DC
# ...

# %%
dc_marvel.to_csv(data_dir + 'DC_Marvel.csv', index = False)

# %% [markdown]
# ----

# %%
#Getting a sample of 20 characters

# %%
characters_20 = dc_marvel.sample(n=20, random_state=1)

# %%
characters_20
# Out:
#                                             name                ID ALIGN  \
# 1738                 LeTonya Charles (New Earth)  Identity Unknown   Bad
# 8033                      Moloka Dar (Earth-616)  No Dual Identity   Bad
# 4248                     Marcia Long (New Earth)   Public Identity  Good
# 3472                    Jamal Stuart (New Earth)   Public Identity  Good
# 12808                Tom Orzechowski (Earth-616)   Public Identity   Bad
# 9361                       Briquette (Earth-616)   Secret Identity   Bad
# 7141                           Quirt (Earth-616)   Public Identity   Bad
# 51                   Theodore Knight (New Earth)   Secret Identity  Good
# 3571                          Seraph (New Earth)   Public Identity  Good
# 3227                        Arrakhat (New Earth)  Identity Unknown   Bad
# 7700                   Efrain Normas (Earth-616)   Secret Identity   Bad
# 11848                          Kalya (Earth-616)   Secret Identity   Bad
# ...

# %%
nodes = characters_20.iloc[:,:1]
nodes
# Out:
#                                             name
# 1738                 LeTonya Charles (New Earth)
# 8033                      Moloka Dar (Earth-616)
# 4248                     Marcia Long (New Earth)
# 3472                    Jamal Stuart (New Earth)
# 12808                Tom Orzechowski (Earth-616)
# 9361                       Briquette (Earth-616)
# 7141                           Quirt (Earth-616)
# 51                   Theodore Knight (New Earth)
# 3571                          Seraph (New Earth)
# 3227                        Arrakhat (New Earth)
# 7700                   Efrain Normas (Earth-616)
# 11848                          Kalya (Earth-616)
# 279                       Enya Wazzo (New Earth)
# 407                     Joshua Foley (Earth-616)
# 5036   Yellow of the Rainbow Raiders (New Earth)
# 223                           Ultron (Earth-616)
# 8733                      Jacob Bolt (Earth-616)
# 3759                         Fashima (Earth-616)
# ...

# %%
edges.to_csv(data_dir + 'edge.csv', index = False)
nodes.to_csv(data_dir + 'node.csv', index = False)
#characters_20.to_csv(data_dir + 'character_20.csv', index = False)
